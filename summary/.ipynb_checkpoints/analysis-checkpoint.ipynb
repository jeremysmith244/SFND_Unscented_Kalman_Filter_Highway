# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('output.txt', header=None)

# %%
df.drop(columns=[0,4],inplace=True)

# %%
df
# Out:
#              1           2          3
# 0    67.605100  101.994000  27.397200
# 1     4.843170    6.184920   1.430430
# 2     3.325000    7.021700   1.705880
# 3     5.153060    6.207670   2.616680
# 4     2.782860    4.703250   2.080050
# ..         ...         ...        ...
# 295   0.910727    1.352160   1.359620
# 296   1.327980    0.461954   0.394116
# 297   2.121760    1.177260   1.120200
# 298   8.202280    8.666740   8.572880
# 299   6.374480    3.505740   3.394000
#
# [300 rows x 3 columns]

# %%
radar = df.loc[list(range(0,300,2))]
laser = df.loc[list(range(1,300,2))]

print(radar[1].mean())
print(laser[1].mean())
# Out:
# 3.692960124000001
# 3.3065637679999993

# %%
plt.plot(df[1]);
plt.plot(df[2]);
plt.plot(df[3]);

# %%
plt.plot(radar[1]);
plt.plot(radar[2]);
plt.plot(radar[3]);
plt.ylim((0,15));
plt.xlabel('k');
plt.ylabel('NIS Radar');
plt.title('{}% of NIS Above 7.8'.format((radar > 7.8).sum().sum()/(300*3)*100))
plt.legend(['Car1', 'Car2', 'Car3'])
plt.axhline(7.8,color='r');
plt.savefig('Radar_NIS.png');

# %%
plt.plot(laser[1]);
plt.plot(laser[2]);
plt.plot(laser[3]);
plt.ylim((0,15));
plt.xlabel('k');
plt.ylabel('NIS Laser');
plt.title('{}% of NIS Above 5.9'.format(str((laser > 5.9).sum().sum()/(300*3)*100)[:3]))
plt.legend(['Car1', 'Car2', 'Car3'])
plt.axhline(5.9,color='r');
plt.savefig('Laser_NIS.png');
